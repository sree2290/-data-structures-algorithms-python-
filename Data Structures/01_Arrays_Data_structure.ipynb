# %% [markdown]
# ## Arrays

# %% [markdown]
# Array : An array is a collection of items stored at contiguous memory locations. The idea is to store multiple items of the same type together. This makes it easier to calculate the position of each element by simply adding an offset to a base value, i.e., the memory location of the first element of the array (generally denoted by the name of the array)

# %% [markdown]
# ![array diagram.png](data:image/png;base64,...)

# %%
import array as arr # importing "array" for array operations

# %%
array = arr.array("i",[87,4,3,2,5,99,987]) # initializing array with array values

# %%
type(array)
# Out:
# array.array

# %%
print(array)
# Out:
# array('i', [87, 4, 3, 2, 5, 99, 987])

# %% [markdown]
# Operations

# %% [markdown]
# Adding elements to an array

# %%
array.append(45) # append will add elements to the end of array

# %%
array
# Out:
# array('i', [87, 4, 3, 2, 5, 99, 987, 45])

# %%
array.insert(1,69) # insert will add elements at given index

# %%
array
# Out:
# array('i', [87, 69, 4, 3, 2, 5, 99, 987, 45])

# %% [markdown]
# Removing elements from an array

# %%
array.pop() # pop() removes the last element of an array
# Out:
# 45

# %%
array
# Out:
# array('i', [87, 69, 4, 3, 2, 5, 99, 987])

# %%
array.remove(99) # remove will remove the element which is first occured specified in the method

# %%
array
# Out:
# array('i', [87, 69, 4, 3, 2, 5, 987])

# %% [markdown]
# Accessing the elements of an array Using Index (refer the above picture for clear understanding of index in array

# %%
array[1] # accessing the first index element
# Out:
# 69

# %%
array[-1] # accessing the last element
# Out:
# 987

# %%
array[2:5]  # accessing elements from index 2 to 4 (not including 5) Also called Slicing
# Out:
# array('i', [4, 3, 2])

# %% [markdown]
# Reversing an array

# %%
array # original Array
# Out:
# array('i', [87, 69, 4, 3, 2, 5, 987])

# %%
array[::-1]  # reversed Array
# Out:
# array('i', [987, 5, 2, 3, 4, 69, 87])

# %% [markdown]
# Searching for an element in array and the get the element index

# %%
search_element = 4
array.index(search_element)
# Out:
# 2

# %%
array # 4 present in array at the index of 2
# Out:
# array('i', [87, 69, 4, 3, 2, 5, 987])

# %% [markdown]
# Iterate over an Array

# %%
for i in array:
    print(i)
# Out:
# 87
# 69
# 4
# 3
# 2
# 5
# 987

# %% [markdown]
# Sort an array

# %%
sorted(array)
# Out:
# [2, 3, 4, 5, 69, 87, 987]
